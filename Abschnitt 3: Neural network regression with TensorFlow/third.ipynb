# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow import keras as ks
import os
import logging
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
logging.getLogger('absl').setLevel(logging.ERROR)

# %%
x_original = tf.range(start=-7, limit=-7 + 3 * 100, delta=3, dtype=tf.int32)
y_original = tf.range(start=3, limit=3 + 3 * 100, delta=3, dtype=tf.int32)


# x_original = np.array([-7.0, -4.0, -1.0, 2.0, 5.0, 8.0, 11.0, 14.0])
# y_original = np.array([3.0, 6.0, 9.0, 12.0, 15.0, 18.0, 21.0, 24.0])
# x = tf.cast(tf.constant(x_original), dtype=tf.float32)
# y = tf.cast(tf.constant(y_original), dtype=tf.float32)

# %%
# x_original = tf.reshape(x_original, shape=(100, 1))
# y_original = tf.reshape(y_original, shape=(100, 1))
# x_original, y_original

# %%
x = tf.identity(x_original)
y = tf.identity(y_original)

# %%
plt.figure(figsize=(24,12))
plt.scatter(x=x, y=y, c='green', label='original data')
plt.legend()
plt.show()

# %%
div = int(len(x)*0.7)

x_train = x[0:div]
y_train = y[0:div]

x_test = x[div:]
y_test = y[div:]

div, x_train, y_train, x_test, y_test
# Out:
# (70,
#  <tf.Tensor: shape=(70,), dtype=int32, numpy=
#  array([ -7,  -4,  -1,   2,   5,   8,  11,  14,  17,  20,  23,  26,  29,
#          32,  35,  38,  41,  44,  47,  50,  53,  56,  59,  62,  65,  68,
#          71,  74,  77,  80,  83,  86,  89,  92,  95,  98, 101, 104, 107,
#         110, 113, 116, 119, 122, 125, 128, 131, 134, 137, 140, 143, 146,
#         149, 152, 155, 158, 161, 164, 167, 170, 173, 176, 179, 182, 185,
#         188, 191, 194, 197, 200], dtype=int32)>,
#  <tf.Tensor: shape=(70,), dtype=int32, numpy=
#  array([  3,   6,   9,  12,  15,  18,  21,  24,  27,  30,  33,  36,  39,
#          42,  45,  48,  51,  54,  57,  60,  63,  66,  69,  72,  75,  78,
#          81,  84,  87,  90,  93,  96,  99, 102, 105, 108, 111, 114, 117,
#         120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156,
#         159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195,
#         198, 201, 204, 207, 210], dtype=int32)>,
#  <tf.Tensor: shape=(30,), dtype=int32, numpy=
#  array([203, 206, 209, 212, 215, 218, 221, 224, 227, 230, 233, 236, 239,
#         242, 245, 248, 251, 254, 257, 260, 263, 266, 269, 272, 275, 278,
#         281, 284, 287, 290], dtype=int32)>,
#  <tf.Tensor: shape=(30,), dtype=int32, numpy=
#  array([213, 216, 219, 222, 225, 228, 231, 234, 237, 240, 243, 246, 249,
#         252, 255, 258, 261, 264, 267, 270, 273, 276, 279, 282, 285, 288,
#         291, 294, 297, 300], dtype=int32)>)

# %%
plt.figure(figsize=(24,12))
plt.scatter(x=x_train, y=y_train, c='blue', label='train data')
plt.scatter(x=x_test, y=y_test, c='green', label='test data')
plt.legend()
plt.show()

# %%
x = tf.reshape(x, (-1, 1))
y = tf.reshape(y, (-1, 1))

x_train = tf.reshape(x_train, (-1, 1))
y_train = tf.reshape(y_train, (-1, 1))

x_test = tf.reshape(x_test, (-1, 1))
y_test = tf.reshape(y_test, (-1, 1))


x, y
# Out:
# (<tf.Tensor: shape=(100, 1), dtype=int32, numpy=
#  array([[ -7],
#         [ -4],
#         [ -1],
#         [  2],
#         [  5],
#         [  8],
#         [ 11],
#         [ 14],
#         [ 17],
#         [ 20],
#         [ 23],
#         [ 26],
#         [ 29],
#         [ 32],
#         [ 35],
#         [ 38],
#         [ 41],
#         [ 44],
#         [ 47],
#         [ 50],
#         [ 53],
#         [ 56],
#         [ 59],
#         [ 62],
#         [ 65],
#         [ 68],
#         [ 71],
#         [ 74],
#         [ 77],
#         [ 80],
#         [ 83],
#         [ 86],
#         [ 89],
#         [ 92],
#         [ 95],
#         [ 98],
#         [101],
#         [104],
#         [107],
#         [110],
#         [113],
#         [116],
#         [119],
#         [122],
#         [125],
#         [128],
#         [131],
#         [134],
#         [137],
#         [140],
#         [143],
#         [146],
#         [149],
#         [152],
#         [155],
#         [158],
#         [161],
#         [164],
#         [167],
#         [170],
#         [173],
#         [176],
#         [179],
#         [182],
#         [185],
#         [188],
#         [191],
#         [194],
#         [197],
#         [200],
#         [203],
#         [206],
#         [209],
#         [212],
#         [215],
#         [218],
#         [221],
#         [224],
#         [227],
#         [230],
#         [233],
#         [236],
#         [239],
#         [242],
#         [245],
#         [248],
#         [251],
#         [254],
#         [257],
#         [260],
#         [263],
#         [266],
#         [269],
#         [272],
#         [275],
#         [278],
#         [281],
#         [284],
#         [287],
#         [290]], dtype=int32)>,
#  <tf.Tensor: shape=(100, 1), dtype=int32, numpy=
#  array([[  3],
#         [  6],
#         [  9],
#         [ 12],
#         [ 15],
#         [ 18],
#         [ 21],
#         [ 24],
#         [ 27],
#         [ 30],
#         [ 33],
#         [ 36],
#         [ 39],
#         [ 42],
#         [ 45],
#         [ 48],
#         [ 51],
#         [ 54],
#         [ 57],
#         [ 60],
#         [ 63],
#         [ 66],
#         [ 69],
#         [ 72],
#         [ 75],
#         [ 78],
#         [ 81],
#         [ 84],
#         [ 87],
#         [ 90],
#         [ 93],
#         [ 96],
#         [ 99],
#         [102],
#         [105],
#         [108],
#         [111],
#         [114],
#         [117],
#         [120],
#         [123],
#         [126],
#         [129],
#         [132],
#         [135],
#         [138],
#         [141],
#         [144],
#         [147],
#         [150],
#         [153],
#         [156],
#         [159],
#         [162],
#         [165],
#         [168],
#         [171],
#         [174],
#         [177],
#         [180],
#         [183],
#         [186],
#         [189],
#         [192],
#         [195],
#         [198],
#         [201],
#         [204],
#         [207],
#         [210],
#         [213],
#         [216],
#         [219],
#         [222],
#         [225],
#         [228],
#         [231],
#         [234],
#         [237],
#         [240],
#         [243],
#         [246],
#         [249],
#         [252],
#         [255],
#         [258],
#         [261],
#         [264],
#         [267],
#         [270],
#         [273],
#         [276],
#         [279],
#         [282],
#         [285],
#         [288],
#         [291],
#         [294],
#         [297],
#         [300]], dtype=int32)>)

# %%
x[0].shape, y[0].shape
# Out:
# (TensorShape([1]), TensorShape([1]))

# %%
tf.random.set_seed(13)

model1 = tf.keras.Sequential([
    tf.keras.layers.Dense(1),
])

model1.compile(loss=tf.keras.losses.mae,
               optimizer=tf.keras.optimizers.SGD(),
               metrics=['mae'])

model1.fit(x_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 0s 15ms/step - loss: 156.0493 - mae: 156.0493
# Epoch 2/100
# 3/3 [==============================] - 0s 6ms/step - loss: 47.6353 - mae: 47.6353
# Epoch 3/100
# 3/3 [==============================] - 0s 6ms/step - loss:
epoch 99/100
# 3/3 [==============================] - 0s 5ms/step - loss: 47.3457 - mae: 47.3457
# Epoch 100/100
# 3/3 [==============================] - 0s 6ms/step - loss: 41.5937 - mae: 41.5937

# %%
y_predicts = model1.predict(x_test)
y_predicts
# Out:
# 1/1 [==============================] - 0s 24ms/step
# array([[ 73.99711 ],
#        [ 75.08464 ],
#        [ 76.17218 ],
#        [ 77.25971 ],
#        [ 78.347244],
#        [ 79.43478 ],
#        [ 80.522316],
#        [ 81.60985 ],
#        [ 82.69738 ],
#        [ 83.78492 ],
#        [ 84.87245 ],
#        [ 85.959984],
#        [ 87.047516],
#        [ 88.135056],
#        [ 89.22259 ],
#        [ 90.31012 ],
#        [ 91.39766 ],
#        [ 92.48519 ],
#        [ 93.57272 ],
#        [ 94.660255],
#        [ 95.747795],
#        [ 96.83533 ],
#        [ 97.92286 ],
#        [ 99.0104  ],
#        [100.09793 ],
#        [101.18546 ],
#        [102.272995],
#        [103.360535],
#        [104.44807 ],
#        [105.5356  ]], dtype=float32)

# %%
y_predicts = model1.predict(x_test)

plt.figure(figsize=(24,12))
plt.scatter(x=x_train, y=y_train, c='blue', label='train data')
plt.scatter(x=x_test, y=y_test, c='green', label='test data')
plt.scatter(x=x_test, y=y_predicts, c='red', label='predict data')
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 0s 12ms/step

# %%
tf.random.set_seed(13)

model2 = ks.Sequential()
model2.add(ks.layers.Input(1,))
model2.add(ks.layers.Dense(10))
model2.add(ks.layers.Dense(1))

model2.compile(loss=tf.keras.losses.mae,
               optimizer=tf.keras.optimizers.SGD(),
               metrics=['mae'])

model2.fit(x_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 0s 16ms/step - loss: 159.6666 - mae: 159.6666
# Epoch 2/100
# 3/3 [==============================] - 0s 6ms/step - loss: 96.1335 - mae: 96.1335
# Epoch 3/100
# 3/3 [==============================] - 0s 6ms/step - loss: 90.0461 - mae: 90.0461
# Epoch 4/100
# 3/3 [==============================] - 0s 6ms/step - loss: 80.7618 - mae: 80.7618
# Epoch 5/100
# 3/3 [==============================] - 0s 5ms/step - loss: 97.0865 - mae: 97.0865
# Epoch 6/100
# 3/3 [==============================] - 0s 6ms/step - loss: 84.1490 - mae: 84.1490
# Epoch 7/100
# 3/3 [==============================] - 0s 6ms/step - loss: 93.5662 - mae: 93.5662
# Epoch 8/100
# 3/3 [==============================] - 0s 4ms/step - loss: 113.6238 - mae: 113.6238
# Epoch 9/100
# 3/3 [==============================] - 0s 5ms/step - loss: 66.1699 - mae: 66.1699
# Epoch 10/100
# 3/3 [==============================] - 0s 4ms/step - loss: 105.7112 - mae: 105.7112
# Epoch 11/100
# 3/3 [==============================] - 0s 4ms/step - loss: 79.1200 - mae: 79.1200
# Epoch 12/100
# 3/3 [==============================] - 0s 5ms/step - loss: 104.9682 - mae: 104.9682
# Epoch 13/100
# 3/3 [==============================] - 0s 4ms/step - loss: 68.0591 - mae: 68.0591
# Epoch 14/100
# 3/3 [==============================] - 0s 5ms/step - loss: 104.7419 - mae: 104.7419
# Epoch 15/100
# 3/3 [==============================] - 0s 5ms/step - loss: 55.6393 - mae: 55.6393
# Epoch 16/100
# 3/3 [==============================] - 0s 5ms/step - loss: 78.2713 - mae: 78.2713
# Epoch 17/100
# 3/3 [==============================] - 0s 5ms/step - loss: 147.6734 - mae: 147.6734
# Epoch 18/100
# 3/3 [==============================] - 0s 5ms/step - loss: 61.6279 - mae: 61.6279
# Epoch 19/100
# 3/3 [==============================] - 0s 5ms/step - loss: 95.9992 - mae: 95.9992
# Epoch 84/100
# 3/3 [==============================] - 0s 5ms/step - loss: 78.8188 - mae: 78.8188
# Epoch 85/100
# 3/3 [==============================] - 0s 5ms/step - loss: 247.5292 - mae: 247.5292
# Epoch 86/100
# 3/3 [==============================] - 0s 5ms/step - loss: 104.1115 - mae: 104.1115
# Epoch 87/100
# 3/3 [==============================] - 0s 5ms/step - loss: 72.8605 - mae: 72.8605
# Epoch 88/100
# 3/3 [==============================] - 0s 5ms/step - loss: 76.7311 - mae: 76.7311
# Epoch 89/100
# 3/3 [==============================] - 0s 5ms/step - loss: 93.7924 - mae: 93.7924
# Epoch 90/100
# 3/3 [==============================] - 0s 5ms/step - loss: 109.7506 - mae: 109.7506
# Epoch 91/100
# 3/3 [==============================] - 0s 4ms/step - loss: 98.8702 - mae: 98.8702
# Epoch 92/100
# 3/3 [==============================] - 0s 5ms/step - loss: 61.3059 - mae: 61.3059
# Epoch 93/100
# 3/3 [==============================] - 0s 4ms/step - loss: 102.4012 - mae: 102.4012
# Epoch 94/100
# 3/3 [==============================] - 0s 5ms/step - loss: 51.0416 - mae: 51.0416
# Epoch 95/100
# 3/3 [==============================] - 0s 5ms/step - loss: 98.2474 - mae: 98.2474
# Epoch 96/100
# 3/3 [==============================] - 0s 5ms/step - loss: 109.0113 - mae: 109.0113
# Epoch 97/100
# 3/3 [==============================] - 0s 5ms/step - loss: 104.7332 - mae: 104.7332
# Epoch 98/100
# 3/3 [==============================] - 0s 5ms/step - loss: 104.5952 - mae: 104.5952
# Epoch 99/100
# 3/3 [==============================] - 0s 4ms/step - loss: 98.2070 - mae: 98.2070
# Epoch 100/100
# 3/3 [==============================] - 0s 5ms/step - loss: 56.7357 - mae: 56.7357

# %%
y_predicts = model2.predict(x_test)
x_test, y_predicts
# Out:
# WARNING:tensorflow:6 out of the last 16 calls to <function Model.make_predict_function.<locals>.predict_function at 0x1775b68b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 16 calls to <function Model.make_predict_function.<locals>.predict_function at 0x1775b68b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 28ms/step
# (<tf.Tensor: shape=(30, 1), dtype=int32, numpy=
#  array([[203],
#         [206],
#         [209],
#         [212],
#         [215],
#         [218],
#         [221],
#         [224],
#         [227],
#         [230],
#         [233],
#         [236],
#         [239],
#         [242],
#         [245],
#         [248],
#         [251],
#         [254],
#         [257],
#         [260],
#         [263],
#         [266],
#         [269],
#         [272],
#         [275],
#         [278],
#         [281],
#         [284],
#         [287],
#         [290]], dtype=int32)>,
#  array([[401.59918],
#         [407.50684],
#         [413.41452],
#         [419.3221 ],
#         [425.2298 ],
#         [431.13745],
#         [437.04507],
#         [442.95276],
#         [448.8604 ],
#         [454.76804],
#         [460.6757 ],
#         [466.58337],
#         [472.491  ],
#         [478.39865],
#         [484.30627],
#         [490.21393],
#         [496.1216 ],
#         [502.02927],
#         [507.9369 ],
#         [513.84454],
#         [519.7522 ],
#         [525.6599 ],
#         [531.56757],
#         [537.4752 ],
#         [543.3828 ],
#         [549.2905 ],
#         [555.1981 ],
#         [561.1058 ],
#         [567.0134 ],
#         [572.9211 ]], dtype=float32))

# %%
plt.figure(figsize=(24,12))
plt.scatter(x=x_train, y=y_train, c='blue', label='train data')
plt.scatter(x=x_test, y=y_test, c='green', label='test data')
plt.scatter(x=x_test, y=y_predicts, c='red', label='predict data')
plt.legend()
plt.show()
